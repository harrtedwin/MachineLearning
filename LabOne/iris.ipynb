# %%
import pandas as pd
irisdf = pd.read_csv('data.csv')

# %%
irisdf.head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#used for expanding the no o viible columns of dataframe

# %%
irisdf.head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
irisdf['Degree of endangerment'].count()
# Out:
# 2722

# %%
irisdf['Degree of endangerment'].value_counts()
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Degree of endangerment, dtype: int64

# %%
irisdf['Degree of endangerment'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
irisdf['Countries'].count()
# Out:
# 2721

# %%
irisdf[['Countries','Degree of endangerment']]
# Out:
#                                               Countries Degree of endangerment
# 0                                                 Italy             Vulnerable
# 1                                                 Italy             Vulnerable
# 2     Germany, Denmark, Netherlands, Poland, Russian...             Vulnerable
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...             Vulnerable
# 4                                    Italy, Switzerland  Definitely endangered
# 5     Albania, Germany, Austria, Belarus, Bosnia and...  Definitely endangered
# 6                                                Israel  Definitely endangered
# 7                                                 India             Vulnerable
# 8                         Germany, Belgium, Netherlands             Vulnerable
# 9                      Bolivia (Plurinational State of)             Vulnerable
# 10                                         India, Nepal             Vulnerable
# ...

# %%
irisdf.loc[:,['Countries','Degree of endangerment']]
# Out:
#                                               Countries Degree of endangerment
# 0                                                 Italy             Vulnerable
# 1                                                 Italy             Vulnerable
# 2     Germany, Denmark, Netherlands, Poland, Russian...             Vulnerable
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...             Vulnerable
# 4                                    Italy, Switzerland  Definitely endangered
# 5     Albania, Germany, Austria, Belarus, Bosnia and...  Definitely endangered
# 6                                                Israel  Definitely endangered
# 7                                                 India             Vulnerable
# 8                         Germany, Belgium, Netherlands             Vulnerable
# 9                      Bolivia (Plurinational State of)             Vulnerable
# 10                                         India, Nepal             Vulnerable
# ...

# %%
eastAfricaCountries = ((irisdf.Countries == "Kenya") |
                       (irisdf.Countries == "Ethiopia") |
                       (irisdf.Countries == "Tanzania") |
                       (irisdf.Countries == "Uganda") |
                       (irisdf.Countries == "Rwanda") |
                       (irisdf.Countries == "Burundi") |
                       (irisdf.Countries == "South Sudan") |
                       (irisdf.Countries == "Somalia")
                      )
irisdf[eastAfricaCountries]
# Out:
#         ID             Name in English Name in French  \
# 195   1686                         Yem            yem
# 421   1684                        Oyda           oyda
# 424    109                        Amba           amba
# 436   1681                       Kwama          kwama
# 572   1685                     Ts'amay      ts'amakko
# 581     88                     Argobba        argobba
# 615     91                       Burji          burji
# 631   1677                       Chara          chara
# 641   1676                       Bussa          bussa
# 649     83                       Dimme           dime
# 699   1671                    Bambassi       bambassi
# 759   1673                      Arbore         arbore
# 805     85                        Nayi           nayi
# 825   1679                       Mursi          mursi
# 836     99                        Boni           boni
# 847     77                        Hozo           hozo
# ...

# %%
irisdf[eastAfricaCountries].count()
# Out:
# ID                             44
# Name in English                44
# Name in French                 44
# Name in Spanish                44
# Countries                      44
# Country codes alpha 3          44
# ISO639-3 codes                 39
# Degree of endangerment         44
# Alternate names                18
# Name in the language            0
# Number of speakers             43
# Sources                        42
# Latitude                       44
# Longitude                      44
# Description of the location     5
# dtype: int64

# %%
eastAfricaCountriesOne = irisdf.Countries.isin(['Kenya','Ethiopia','Tanzania','Uganda','Rwanda','Burundi','South Sudan','Somalia'])
irisdf[eastAfricaCountriesOne]
# Out:
#         ID             Name in English Name in French  \
# 195   1686                         Yem            yem
# 421   1684                        Oyda           oyda
# 424    109                        Amba           amba
# 436   1681                       Kwama          kwama
# 572   1685                     Ts'amay      ts'amakko
# 581     88                     Argobba        argobba
# 615     91                       Burji          burji
# 631   1677                       Chara          chara
# 641   1676                       Bussa          bussa
# 649     83                       Dimme           dime
# 699   1671                    Bambassi       bambassi
# 759   1673                      Arbore         arbore
# 805     85                        Nayi           nayi
# 825   1679                       Mursi          mursi
# 836     99                        Boni           boni
# 847     77                        Hozo           hozo
# ...

# %%
is_missing_Country =irisdf['Countries'].isnull()
irisdf[is_missing_Country]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 405  1680            Boro           boro            boro       NaN
#
#     Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 405                   NaN            bwo  Definitely endangered
#
#     Alternate names Name in the language  Number of speakers  \
# 405        Shinasha                  NaN             19878.0
#
#                     Sources  Latitude  Longitude Description of the location
# 405  Census, Zelealem Leyew   10.3581    35.0024                         NaN

# %%
irisdf[eastAfricaCountries].loc[:,['Countries','Degree of endangerment']]
# Out:
#      Countries Degree of endangerment
# 195   Ethiopia             Vulnerable
# 421   Ethiopia             Vulnerable
# 424     Uganda             Vulnerable
# 436   Ethiopia             Vulnerable
# 572   Ethiopia  Definitely endangered
# 581   Ethiopia  Critically endangered
# 615      Kenya             Vulnerable
# 631   Ethiopia             Vulnerable
# 641   Ethiopia             Vulnerable
# 649   Ethiopia             Vulnerable
# 699   Ethiopia  Definitely endangered
# 759   Ethiopia  Definitely endangered
# 805   Ethiopia             Vulnerable
# 825   Ethiopia             Vulnerable
# 836      Kenya  Definitely endangered
# 847   Ethiopia  Definitely endangered
# 951   Ethiopia  Definitely endangered
# 961   Ethiopia  Definitely endangered
# 966     Uganda    Severely endangered
# 1060  Ethiopia    Severely endangered
# 1152     Kenya  Definitely endangered
# 1222  Ethiopia    Severely endangered
# 1371  Ethiopia  Critically endangered
# 1434  Ethiopia    Severely endangered
# ...

# %%
irisdf[eastAfricaCountries].loc[:,['Degree of endangerment']]
# Out:
#      Degree of endangerment
# 195              Vulnerable
# 421              Vulnerable
# 424              Vulnerable
# 436              Vulnerable
# 572   Definitely endangered
# 581   Critically endangered
# 615              Vulnerable
# 631              Vulnerable
# 641              Vulnerable
# 649              Vulnerable
# 699   Definitely endangered
# 759   Definitely endangered
# 805              Vulnerable
# 825              Vulnerable
# 836   Definitely endangered
# 847   Definitely endangered
# 951   Definitely endangered
# 961   Definitely endangered
# 966     Severely endangered
# 1060    Severely endangered
# 1152  Definitely endangered
# 1222    Severely endangered
# 1371  Critically endangered
# 1434    Severely endangered
# 1458    Severely endangered
# 1523  Critically endangered
# 1640  Critically endangered
# 1653  Critically endangered
# 1751  Critically endangered
# 1798  Critically endangered
# 1911  Critically endangered
# 2142  Critically endangered
# ...

# %%
irisdf[eastAfricaCountries].loc[:,['Degree of endangerment']].value_counts()
# Out:
# Degree of endangerment
# Extinct                   12
# Vulnerable                10
# Critically endangered      9
# Definitely endangered      8
# Severely endangered        5
# dtype: int64

# %%
NumberOfEndangeredEastAfricaLanguages = irisdf[eastAfricaCountries].loc[:,['Degree of endangerment']].value_counts()

# %%
print(NumberOfEndangeredEastAfricaLanguages)
# Out:
# Degree of endangerment
# Extinct                   12
# Vulnerable                10
# Critically endangered      9
# Definitely endangered      8
# Severely endangered        5
# dtype: int64

# %%
NumberOfEndangeredEastAfricaLanguages.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Degree of endangerment'>

# %%
lookCountryAngola = irisdf.Countries.isin(['Angola'])
irisdf[lookCountryAngola]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                    ANG            blv  Definitely endangered
# 2385                   ANG            NaN                Extinct
# 2402                   ANG            kwz                Extinct
# 2403                   ANG            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...

# %%
wrongCountryCodeAngola = irisdf[lookCountryAngola].loc[:,['Country codes alpha 3']]
print(wrongCountryCodeAngola)
# Out:
#      Country codes alpha 3
# 891                    ANG
# 2385                   ANG
# 2402                   ANG
# 2403                   ANG

# %% [markdown]
# ## Country code for Angola is AO but from the data provided it is given ANG. Task is to change it from ANG to AO, affected rows are only four.

# %%
# replacing it on the function wrongCountryCodeAngola to confirm it works before replacing it on the dataframe irisdf
wrongCountryCodeAngola.replace("ANG", "AO", inplace=True)
print(wrongCountryCodeAngola)
# Out:
#      Country codes alpha 3
# 891                     AO
# 2385                    AO
# 2402                    AO
# 2403                    AO

# %%
#replacing it on the main dataframe irisdf
irisdf.replace("ANG", "AO", inplace=True)

# %%
rightCountryCodeAngola = irisdf[lookCountryAngola].loc[:,['Country codes alpha 3']]
print(rightCountryCodeAngola)
# Out:
#      Country codes alpha 3
# 891                     AO
# 2385                    AO
# 2402                    AO
# 2403                    AO

# %%
lookCountryAngola = irisdf.Countries.isin(['Angola'])
irisdf[lookCountryAngola]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                     AO            blv  Definitely endangered
# 2385                    AO            NaN                Extinct
# 2402                    AO            kwz                Extinct
# 2403                    AO            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...
